# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\SarahSamir\Desktop\python\ranges_cleaned.csv")
df
# Out:
#        Unnamed: 0          Gene.ID         symbol chromosome_name chr_num  \
# 0               1  ENSG00000000003         tspan6            chrx       x
# 1               2  ENSG00000000419           dpm1           chr20      20
# 2               3  ENSG00000000457          scyl3            chr1       1
# 3               4  ENSG00000000460       c1orf112            chr1       1
# 4               5  ENSG00000000971            cfh            chr1       1
# ...           ...              ...            ...             ...     ...
# 17908       17909  ENSG00000273456   rp11-686o6.2            chr2       2
# 17909       17910  ENSG00000273471  rp13-1039j1.4            chr2       2
# 17910       17911  ENSG00000273472  rp11-102n12.3            chr4       4
# 17911       17912  ENSG00000273483   rp4-671g15.2            chr1       1
# 17912       17913  ENSG00000273485  rp11-225h22.7           chr10      10
#
#        start_position  end_position  baseMean  log2FoldChange     lfcSE  \
# ...

# %%
df["chromosome_name"].value_counts().plot(kind='bar', title='Chromosome Counts')
# Out:
# <Axes: title={'center': 'Chromosome Counts'}, xlabel='chromosome_name'>

# %%
cv = df["chromosome_name"].value_counts()
cv.plot(color="pink",linewidth=8, title='Chromosome Counts')
# Out:
# <Axes: title={'center': 'Chromosome Counts'}, xlabel='chromosome_name'>

# %%
df.rename(columns={"chromosome_name": "chromosome", "gene_lengh": "gene_length"}, inplace=True) #inplace =True modifies the original DataFrame
sarah = df.groupby( "chromosome")["gene_length"]

# %%
# Aggregate gene_length by chromosome and plot as bar
sarah.sum().plot(kind='bar', color="yellow", title="Total Gene Length by Chromosome")
# Out:
# <Axes: title={'center': 'Total Gene Length by Chromosome'}, xlabel='chromosome'>

# %%
df.plot( y="baseMean", x="log2FoldChange", kind="scatter", color="red", title="Base Mean vs Log2 Fold Change")
# Out:
# <Axes: title={'center': 'Base Mean vs Log2 Fold Change'}, xlabel='log2FoldChange', ylabel='baseMean'>
